# %% [markdown]
# <a href="https://colab.research.google.com/github/maede13828890-sudo/dataScience_class/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# module explanation
# تابعی نوشته که یک ورودی از کاربر گرفته و توان دوی آن را چاپ کند


def my_pow(x):
    power = x ** 2
    return power


if __name__ == "__main__":
    number = int(input("Please enter a number:"))

    print(my_pow(number))
# Out:
# Please enter a number:4
# 16
